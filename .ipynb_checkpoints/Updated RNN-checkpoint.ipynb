# %%
import re
import sys
import warnings
import scipy.stats

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from time import sleep
from nltk.corpus import stopwords
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential, load_model
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.layers import Dense, LSTM, Embedding, Dropout

warnings.filterwarnings('ignore')

# %% [markdown]
# Load and Process Dataset

# %%
def get_data(headers, dtypes, filename):
    data = pd.read_csv(filename, encoding='utf8', skiprows=[0], names=headers, dtype=dtypes, na_filter=False)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

hv = ['Anonymized Message', 'Valence']
dtv = {'Anonymized Message':'str', 'Valence':'float'}
v_data = get_data(hv, dtv, "Valence_Data.csv")

ha = ['Anonymized Message', 'Arousal']
dta = {'Anonymized Message':'str', 'Arousal':'float'}
a_data = get_data(ha, dta, "Arousal_Data.csv")

# %% [markdown]
# Pre-processing

# %%
def preprocess(messages):
    # set all words to lowercase and remove anything that isn't a letter or space
    messages = messages.apply(lambda x: x.lower()) #transform text to lowercase
    messages = messages.apply(lambda x: re.sub('[^a-zA-z0-9\s]', '', x))

    # find and remove all stop words
    stop = stopwords.words('english')
    messages = messages.apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
    return messages

vX = preprocess(v_data['Anonymized Message'])
vy = v_data['Valence']

aX = preprocess(a_data['Anonymized Message'])
ay = a_data['Arousal']

# %% [markdown]
# Create Models

# %%
def get_model(Xin, yin):
    # setup a tokenizer to keep the most frequent 5000 words
    tokenizer = Tokenizer(num_words=2000, split=" ")
    tokenizer.fit_on_texts(Xin.values)
    
    # define input X
    X = tokenizer.texts_to_sequences(Xin.values)
    X = pad_sequences(X) # padding our text vector so they all have the same length
    
    # define expected output for training and testing
    y = pd.get_dummies(yin).values
    
    # setup and establish model with 9 outputs
    # output will be an array of length 9. 
    # the highest output value corresponds to the model's guess
    model = Sequential()
    model.add(Embedding(2000, 64, input_length=X.shape[1]))
    model.add(Dropout(0.3))
    model.add(LSTM(64, return_sequences=True, dropout=0.3, recurrent_dropout=0.2))
    model.add(LSTM(264, dropout=0.3, recurrent_dropout=0.2))
    model.add(Dense(9, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    
    y = pd.get_dummies(yin).values
    
    # split X, y into training and testing 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    
    return model, X_train, X_test, y_train, y_test

v_model, v_xtrain, v_xtest, v_ytrain, v_ytest = get_model(vX, vy)
a_model, a_xtrain, a_xtest, a_ytrain, a_ytest = get_model(aX, ay)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 44, 64)            128000
#
#  dropout_13 (Dropout)        (None, 44, 64)            0
#
#  lstm_26 (LSTM)              (None, 44, 64)            33024
#
#  lstm_27 (LSTM)              (None, 264)               347424
#
#  dense_13 (Dense)            (None, 9)                 2385
#
# =================================================================
# Total params: 510,833
# Trainable params: 510,833
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_14 (Embedding)    (None, 98, 64)            128000
#
#  dropout_14 (Dropout)        (None, 98, 64)            0
#
#  lstm_28 (LSTM)              (None, 98, 64)            33024
#
#  lstm_29 (LSTM)              (None, 264)               347424
#
#  dense_14 (Dense)            (None, 9)                 2385
#
# =================================================================
# Total params: 510,833
# Trainable params: 510,833
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training Model(s)

# %%
def train_model(model, X, y):
    k = 10
    epochs = 8
    batch_size = 32
    kf = KFold(n_splits=k, random_state=None)
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index, :], X[test_index, :]
        y_train, y_test = y[train_index, :], y[test_index, :]
      
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2)
        
        results= model.predict(X_test)
        preds = []
        actual = []
        for pred in results:
            preds.append(np.argmax(pred) + 1)
            
        for acts in y_test:
            actual.append(np.argmax(acts) + 1)
            
        r_val = scipy.stats.pearsonr(preds, actual)[0]
        print("R-val score of %.2f" % r_val)
    return model

print("Starting Valence training")
v_model = train_model(v_model, v_xtrain, v_ytrain)
v_model.save('valence_analysis.h5')

print("Finished Valence training. Now starting Arousal training")
a_model = train_model(a_model, a_xtrain, a_ytrain)
a_model.save('arousal_analysis.h5')
# Out:
# Epoch 1/8
# 131/131 - 22s - loss: 2.0373 - accuracy: 0.2182 - 22s/epoch - 170ms/step
# Epoch 2/8
# 131/131 - 19s - loss: 1.5156 - accuracy: 0.4213 - 19s/epoch - 146ms/step
# Epoch 3/8
# 131/131 - 19s - loss: 1.1888 - accuracy: 0.5307 - 19s/epoch - 147ms/step
# Epoch 4/8
# 131/131 - 19s - loss: 1.0436 - accuracy: 0.5910 - 19s/epoch - 147ms/step
# Epoch 5/8
# 131/131 - 19s - loss: 0.9742 - accuracy: 0.6263 - 19s/epoch - 149ms/step
# Epoch 6/8
# 131/131 - 20s - loss: 0.9065 - accuracy: 0.6486 - 20s/epoch - 151ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.8883 - accuracy: 0.6579 - 20s/epoch - 152ms/step
# Epoch 8/8
# 131/131 - 20s - loss: 0.8494 - accuracy: 0.6769 - 20s/epoch - 152ms/step
# R-val score of 0.91
# Epoch 1/8
# 131/131 - 20s - loss: 0.8535 - accuracy: 0.6798 - 20s/epoch - 150ms/step
# Epoch 2/8
# 131/131 - 20s - loss: 0.8099 - accuracy: 0.6896 - 20s/epoch - 151ms/step
# Epoch 3/8
# 131/131 - 21s - loss: 0.7884 - accuracy: 0.6916 - 21s/epoch - 157ms/step
# Epoch 4/8
# 131/131 - 21s - loss: 0.7718 - accuracy: 0.7069 - 21s/epoch - 161ms/step
# Epoch 5/8
# 131/131 - 20s - loss: 0.7496 - accuracy: 0.7170 - 20s/epoch - 155ms/step
# Epoch 6/8
# 131/131 - 21s - loss: 0.7344 - accuracy: 0.7208 - 21s/epoch - 159ms/step
# Epoch 7/8
# 131/131 - 23s - loss: 0.7083 - accuracy: 0.7280 - 23s/epoch - 174ms/step
# Epoch 8/8
# 131/131 - 20s - loss: 0.6953 - accuracy: 0.7376 - 20s/epoch - 154ms/step
# R-val score of 0.94
# Epoch 1/8
# 131/131 - 20s - loss: 0.7225 - accuracy: 0.7235 - 20s/epoch - 156ms/step
# Epoch 2/8
# 131/131 - 21s - loss: 0.7222 - accuracy: 0.7302 - 21s/epoch - 157ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.6796 - accuracy: 0.7326 - 20s/epoch - 155ms/step
# Epoch 4/8
# 131/131 - 21s - loss: 0.6691 - accuracy: 0.7482 - 21s/epoch - 157ms/step
# Epoch 5/8
# 131/131 - 21s - loss: 0.6471 - accuracy: 0.7518 - 21s/epoch - 158ms/step
# Epoch 6/8
# 131/131 - 20s - loss: 0.6328 - accuracy: 0.7580 - 20s/epoch - 155ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.6244 - accuracy: 0.7600 - 20s/epoch - 152ms/step
# Epoch 8/8
# 131/131 - 20s - loss: 0.6179 - accuracy: 0.7600 - 20s/epoch - 152ms/step
# R-val score of 0.96
# Epoch 1/8
# 131/131 - 20s - loss: 0.6252 - accuracy: 0.7607 - 20s/epoch - 154ms/step
# Epoch 2/8
# 131/131 - 20s - loss: 0.6065 - accuracy: 0.7684 - 20s/epoch - 153ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.5978 - accuracy: 0.7700 - 20s/epoch - 152ms/step
# Epoch 4/8
# 131/131 - 20s - loss: 0.5835 - accuracy: 0.7811 - 20s/epoch - 153ms/step
# Epoch 5/8
# 131/131 - 20s - loss: 0.5781 - accuracy: 0.7799 - 20s/epoch - 152ms/step
# Epoch 6/8
# 131/131 - 21s - loss: 0.5713 - accuracy: 0.7784 - 21s/epoch - 158ms/step
# Epoch 7/8
# 131/131 - 22s - loss: 0.5576 - accuracy: 0.7777 - 22s/epoch - 168ms/step
# Epoch 8/8
# 131/131 - 21s - loss: 0.5442 - accuracy: 0.7866 - 21s/epoch - 164ms/step
# R-val score of 0.96
# Epoch 1/8
# 131/131 - 22s - loss: 0.5686 - accuracy: 0.7782 - 22s/epoch - 166ms/step
# Epoch 2/8
# 131/131 - 21s - loss: 0.5583 - accuracy: 0.7880 - 21s/epoch - 158ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.5368 - accuracy: 0.7873 - 20s/epoch - 152ms/step
# Epoch 4/8
# 131/131 - 20s - loss: 0.5296 - accuracy: 0.7914 - 20s/epoch - 152ms/step
# Epoch 5/8
# 131/131 - 21s - loss: 0.5310 - accuracy: 0.7890 - 21s/epoch - 159ms/step
# Epoch 6/8
# 131/131 - 20s - loss: 0.5200 - accuracy: 0.7921 - 20s/epoch - 152ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.5108 - accuracy: 0.8003 - 20s/epoch - 154ms/step
# Epoch 8/8
# 131/131 - 20s - loss: 0.5149 - accuracy: 0.7984 - 20s/epoch - 156ms/step
# R-val score of 0.96
# Epoch 1/8
# 131/131 - 21s - loss: 0.5434 - accuracy: 0.7900 - 21s/epoch - 158ms/step
# Epoch 2/8
# 131/131 - 20s - loss: 0.5248 - accuracy: 0.7943 - 20s/epoch - 152ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.5093 - accuracy: 0.8012 - 20s/epoch - 156ms/step
# Epoch 4/8
# 131/131 - 21s - loss: 0.4934 - accuracy: 0.8068 - 21s/epoch - 163ms/step
# Epoch 5/8
# 131/131 - 20s - loss: 0.4949 - accuracy: 0.8056 - 20s/epoch - 153ms/step
# Epoch 6/8
# 131/131 - 20s - loss: 0.4981 - accuracy: 0.8070 - 20s/epoch - 154ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.4883 - accuracy: 0.8072 - 20s/epoch - 156ms/step
# Epoch 8/8
# 131/131 - 20s - loss: 0.4820 - accuracy: 0.8060 - 20s/epoch - 152ms/step
# R-val score of 0.95
# Epoch 1/8
# 131/131 - 20s - loss: 0.5071 - accuracy: 0.7988 - 20s/epoch - 152ms/step
# Epoch 2/8
# 131/131 - 20s - loss: 0.4937 - accuracy: 0.8029 - 20s/epoch - 154ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.4859 - accuracy: 0.8044 - 20s/epoch - 153ms/step
# Epoch 4/8
# 131/131 - 20s - loss: 0.4714 - accuracy: 0.8113 - 20s/epoch - 155ms/step
# Epoch 5/8
# 131/131 - 20s - loss: 0.4762 - accuracy: 0.8070 - 20s/epoch - 154ms/step
# Epoch 6/8
# 131/131 - 20s - loss: 0.4657 - accuracy: 0.8087 - 20s/epoch - 156ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.4684 - accuracy: 0.8116 - 20s/epoch - 153ms/step
# Epoch 8/8
# 131/131 - 21s - loss: 0.4598 - accuracy: 0.8092 - 21s/epoch - 157ms/step
# R-val score of 0.96
# Epoch 1/8
# 131/131 - 20s - loss: 0.4999 - accuracy: 0.8020 - 20s/epoch - 156ms/step
# Epoch 2/8
# 131/131 - 21s - loss: 0.4621 - accuracy: 0.8159 - 21s/epoch - 163ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.4658 - accuracy: 0.8159 - 20s/epoch - 155ms/step
# Epoch 4/8
# 131/131 - 20s - loss: 0.4518 - accuracy: 0.8195 - 20s/epoch - 153ms/step
# Epoch 5/8
# 131/131 - 20s - loss: 0.4467 - accuracy: 0.8171 - 20s/epoch - 154ms/step
# Epoch 6/8
# 131/131 - 21s - loss: 0.4402 - accuracy: 0.8224 - 21s/epoch - 158ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.4458 - accuracy: 0.8219 - 20s/epoch - 150ms/step
# Epoch 8/8
# 131/131 - 21s - loss: 0.4391 - accuracy: 0.8236 - 21s/epoch - 162ms/step
# R-val score of 0.96
# Epoch 1/8
# 131/131 - 21s - loss: 0.4573 - accuracy: 0.8195 - 21s/epoch - 159ms/step
# Epoch 2/8
# 131/131 - 25s - loss: 0.4433 - accuracy: 0.8190 - 25s/epoch - 194ms/step
# Epoch 3/8
# 131/131 - 24s - loss: 0.4488 - accuracy: 0.8209 - 24s/epoch - 187ms/step
# Epoch 4/8
# 131/131 - 22s - loss: 0.4361 - accuracy: 0.8197 - 22s/epoch - 167ms/step
# Epoch 5/8
# 131/131 - 21s - loss: 0.4280 - accuracy: 0.8202 - 21s/epoch - 164ms/step
# Epoch 6/8
# 131/131 - 21s - loss: 0.4266 - accuracy: 0.8226 - 21s/epoch - 157ms/step
# Epoch 7/8
# 131/131 - 21s - loss: 0.4267 - accuracy: 0.8257 - 21s/epoch - 157ms/step
# Epoch 8/8
# 131/131 - 21s - loss: 0.4249 - accuracy: 0.8253 - 21s/epoch - 160ms/step
# R-val score of 0.97
# Epoch 1/8
# 131/131 - 22s - loss: 0.4509 - accuracy: 0.8200 - 22s/epoch - 165ms/step
# Epoch 2/8
# 131/131 - 21s - loss: 0.4383 - accuracy: 0.8241 - 21s/epoch - 157ms/step
# Epoch 3/8
# 131/131 - 20s - loss: 0.4291 - accuracy: 0.8311 - 20s/epoch - 153ms/step
# Epoch 4/8
# 131/131 - 21s - loss: 0.4232 - accuracy: 0.8258 - 21s/epoch - 157ms/step
# Epoch 5/8
# 131/131 - 21s - loss: 0.4321 - accuracy: 0.8275 - 21s/epoch - 158ms/step
# Epoch 6/8
# 131/131 - 20s - loss: 0.4242 - accuracy: 0.8289 - 20s/epoch - 155ms/step
# Epoch 7/8
# 131/131 - 20s - loss: 0.4262 - accuracy: 0.8263 - 20s/epoch - 154ms/step
# Epoch 8/8
# 131/131 - 20s - loss: 0.4213 - accuracy: 0.8241 - 20s/epoch - 153ms/step
# R-val score of 0.97
# Epoch 1/8
# 131/131 - 52s - loss: 2.1812 - accuracy: 0.1407 - 52s/epoch - 393ms/step
# Epoch 2/8
# 131/131 - 46s - loss: 1.9375 - accuracy: 0.2700 - 46s/epoch - 355ms/step
# Epoch 3/8
# 131/131 - 56s - loss: 1.6598 - accuracy: 0.3709 - 56s/epoch - 426ms/step
# Epoch 4/8

# %% [markdown]
# Testing Model

# %%
def test_model(col, model, X_test, y_test):
    # make predictions
    predictions = model.predict(X_test)
    
    # establish confusion matrix
    confusion = np.zeros([9,9])
    confusionA = np.zeros([9,9])
    correct = 0
    total = 0
    pred_vals = []
    actual_vals = []
    for i, prediction in enumerate(predictions):
        total += 1
        guess_i = np.argmax(prediction)
        actual_i = np.argmax(y_test[i])
        confusion[actual_i][guess_i] += 1
        if guess_i == actual_i:
            correct += 1
            confusionA[actual_i][guess_i] += 1
        pred_vals.append(guess_i + 1)
        actual_vals.append(actual_i + 1)

    r_val = scipy.stats.pearsonr(pred_vals, actual_vals)[0]
    acc = correct/total * 100

    print('%s model has an accuracy of %.2f%%' % (col, acc))
    print('%s model has a correlation coefficient of %.2f' % (col, r_val))
    
    # normalize confusion matrix
    for i in range(0, 9):
        sum = confusion[i].sum()
        if sum > 0:
            confusion[i] = confusion[i] / sum
       

    # plot results
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(confusion)
    fig.colorbar(cax)
    
    categories = [1, 2, 3, 4, 5, 6, 7, 8, 9]
    ax.set_xticklabels([''] + categories, rotation=90)
    ax.set_yticklabels([''] + categories)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    
    plt.xlabel('model output')
    plt.ylabel('actual')
    plt.title(col)
    
    plt.show()

    
    # plot results
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(confusionA)
    fig.colorbar(cax)
    
    categories = [1, 2, 3, 4, 5, 6, 7, 8, 9]
    ax.set_xticklabels([''] + categories, rotation=90)
    ax.set_yticklabels([''] + categories)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    
    plt.xlabel('model output')
    plt.ylabel('actual')
    plt.title(col)
    
    plt.show()
    
# make and plot predictions
test_model('Valence', v_model, v_xtest, v_ytest)
test_model('Arousal', a_model, a_xtest, a_ytest)
# Out:
# Valence model has an accuracy of 69.95%
# Valence model has a correlation coefficient of 0.93
